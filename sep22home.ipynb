# %% [markdown]
# # PYTHON HOMEWORK
# ## Date: 22 September 2026
# ## TOPIC: STRING INDEXING
# ### TASK: Performing 10 differents indexing operation on your name.

# %%
Name="Pavan patil"
print(Name)
print(Name[0] )
print(Name[-1])
print(Name[len(Name)-2])
print(Name[1+2])
s=6
print(Name[s])

mid_char=Name[len(Name)//2]
print(mid_char)

last_third_char=Name[len(Name)-3]
print(last_third_char)

print(Name[10-5])
print(Name[-1+10])
print(Name[len(Name)-len(Name)])
print(Name[len(Name)-len(Name)+6])
print(Name[0],Name[1],Name[2],Name[3],Name[4])
print(Name[4],Name[3],Name[2],Name[1],Name[0])
print(Name[6],Name[7],Name[8],Name[9],Name[10])
print(Name[10],Name[9],Name[8],Name[7],Name[6])
# Out:
# Pavan patil
# P
# l
# i
# a
# p
#
# t
#
# i
# P
# p
# P a v a n
# n a v a P
# p a t i l
# l i t a p
